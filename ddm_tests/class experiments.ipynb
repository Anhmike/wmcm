# %%
import datetime as dt
import pandas as pd
import numpy as np
from pandas_datareader import data
import statsmodels.formula.api as sm

import wmcm

# %%
## I get warnings on the following test. These warnings don't go away, even when I utilize .loc(:, ).
## Leaving it without the verbose stuff which appears to function identically.
## Uncomment this cell for the full traceback.

# import traceback
# import warnings
# import sys

# def warn_with_traceback(message, category, filename, lineno, file=None, line=None):
#     traceback.print_stack()
#     log = file if hasattr(file,'write') else sys.stderr
#     log.write(warnings.formatwarning(message, category, filename, lineno, line))

# warnings.showwarning = warn_with_traceback

# %%
test = wmcm.stock(tic='PG', interval='d')
test.returns_d
# Out:
# /home/daniel/wmcm/wmcm/functions.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['lastClose'] = df['close'].shift(1)
#                  open       high        low      close    volume    ret_cc  \
# Date
# 2010-01-04        NaN        NaN        NaN        NaN   9190800       NaN
# 2010-01-05  49.741287  49.863339  49.310025  49.749422   8649400       NaN
# 2010-01-06  49.586683  49.602957  49.228657  49.513449   9908400 -0.004755
# 2010-01-07  49.293754  49.391397  49.017097  49.244931   8972800 -0.005438
# 2010-01-08  49.114740  49.253067  48.870631  49.179834   8464600 -0.001323
# 2010-01-11  48.886906  49.041506  48.016247  48.984548  14774600 -0.003979
# 2010-01-12  49.391396  49.928436  49.228656  49.545997  13460700  0.011397
# ...

# %%
test2 = wmcm.stock('PG', interval = 'w')
test2.returns_w
# Out:
# /home/daniel/wmcm/wmcm/functions.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['lastClose'] = df['close'].shift(1)
#                  open       high        low      close    volume    ret_cc  \
# Date
# 2010-01-04        NaN        NaN        NaN        NaN   9037200       NaN
# 2010-01-11  48.886904  50.335283  48.016245  49.489038  14022200       NaN
# 2010-01-19  49.472765  50.310875  48.187126  49.074055  13784200 -0.008421
# 2010-01-25  49.852575  51.885032  49.131380  50.442641  16787000  0.027506
# 2010-02-01  50.688499  51.663753  49.524755  50.237753  14164600 -0.004070
# 2010-02-08  50.041067  50.942560  49.836182  50.614742  11857000  0.007476
# 2010-02-16  51.303155  52.237433  51.098270  51.999766  14066000  0.026996
# ...
