# %%
import datetime as dt
import pandas as pd
import numpy as np
from pandas_datareader import data
import statsmodels.formula.api as sm
import seaborn as sns
import wmcm
# %matplotlib inline

# %%
results = pd.read_csv('outputs/first_pass_results.csv', index_col=0)
results.dropna(inplace=True)
results.head()
# Out:
#                     company_name index_weight sector        sector_name  \
# PG              Procter & Gamble       11.90%    XLP  Consumper Staples
# KO                  Coca-Cola Co        9.31%    XLP  Consumper Staples
# PM   Philip Morris International        7.61%    XLP  Consumper Staples
# CVS       CVS Health Corporation        6.16%    XLP  Consumper Staples
# MO              Altria Group Inc        5.84%    XLP  Consumper Staples
#
#      w_e_alpha  w_e_beta_market  w_e_beta_sec_lag  wo_e_alpha  \
# PG    0.000299         0.496863         -0.034772    0.000299
# KO    0.001623         0.447624         -0.450140    0.001623
# PM    0.001119         0.699200         -0.060929    0.001119
# CVS   0.002213         0.745224          0.086654    0.002213
# MO    0.003461         0.466820         -0.021856    0.003461
#
#      wo_e_beta_market  wo_e_beta_sec_lag
# PG           0.496863          -0.034772
# KO           0.447624          -0.450140
# ...

# %%
sns.distplot(results['w_e_beta_sec_lag'])
# Out:
# /home/daniel/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
    sns.distplot(results['wo_e_beta_sec_lag'])
# Out:
# /home/daniel/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(results['wo_e_beta_market'])
# Out:
# /home/daniel/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(results['w_e_beta_market'])
# Out:
# /home/daniel/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
